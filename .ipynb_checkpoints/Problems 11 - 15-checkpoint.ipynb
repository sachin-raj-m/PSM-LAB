# %% [markdown]
# ## 11. Frequency of Numbers, Characters from a File

# %%
filename = input("Enter File Name:")
f1 = open(filename,"w")
print("Enter Elements:")
f1.write(input())
f1.close()

with open(filename,"r") as f2:
    contents = f2.read()
nlist = contents.split()

uppercount = 0
lowercount = 0
digitcount = 0

for ch in contents:
    if (ch.isupper()):
        uppercount+=1
    if (ch.islower()):
        lowercount+=1
    if (ch.isdigit()):
        digitcount+=1
    
print("Total Number of Upper Case Letters : ",uppercount)
print("Total Number of Lower Case Letters : ",lowercount)
print("Total Number of Digits : ",digitcount)
print("Total Number of Words : ",len(nlist))
# Out:
# Enter File Name:hello
# Enter Elements:
# Sachin Raj hii 76
# Total Number of Upper Case Letters :  2
# Total Number of Lower Case Letters :  10
# Total Number of Digits :  2
# Total Number of Words :  4

# %% [markdown]
# ## 12. y = f(x).

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1,5)
y = x**3
fig = plt.figure()
plt.plot(x,y,"r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 13. The areas of the various continents of the world (in millions of square miles) are as
# ## follows:11.7 for Africa; 10.4 for Asia; 1.9 for Europe; 9.4 for North America; 3.3
# ## Oceania; 6.9 South America; 7.9 Soviet Union. Draw a bar chart representing the
# ## given data.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Africa","Asia","Europe","N.America","Oceania","S.America","S.U"])
y = np.array([11.7,10.4,1.9,9.4,3.3,6.9,7.9])
plt.bar(x,y,width = 0.7,color=['blue','green'])
plt.xlabel("Continents")
plt.ylabel("Area")
plt.title("Barchart")
plt.show()

# %% [markdown]
# ## 14. Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %% [markdown]
# ## 15. Table contains population and murder rates (in units of murders per 100,000 people per year) for different states. Compute the mean, median and variance for the population.
#
# ## State Population Murder
# ## Alabama 4,779,736 5.7
# ## Alaska 710,231 5.6
# ## Arizona 6,392,017 4.7
# ## Arkansas 2,915,918 5.6
# ## California 37,253,956 4.4
# ## Colorado 5,029,196 2.8
# ## Connecticut 3,574,097 2.4
# ## Delaware 897,934 5.8

# %%
import numpy as np
from statistics import variance
list1 = [4779736, 710231, 6392017, 2915918, 37253956, 5029196, 3574097, 897934]
#mean = sum(list1)/len(list1)
#print("Mean=",mean)

#list1.sort()
#if(len(list1)%2==0):
    #a = (int)(len(list1)/2)
    #median = (list1[a] + list1[a+1])/2
    #print("Median = ",median)
#else:
    #a = list1[len(list1)//2]
    #print("Median = ",a)


print("Variance = ", variance(list1))
print("Mean = ", np.mean(list1))
print("Median = ", np.median(list1))
# Out:
# Variance =  146549069168147.7
# Mean =  7694135.625
# Median =  4176916.5
